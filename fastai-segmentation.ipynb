# %% [markdown]
# ## Image segmentation with CamVid

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
path = untar_data(URLs.CAMVID)
path.ls()
# Out:
# ...
# [PosixPath('/root/.fastai/data/camvid/labels'),
#  PosixPath('/root/.fastai/data/camvid/images'),
#  PosixPath('/root/.fastai/data/camvid/valid.txt'),
#  PosixPath('/root/.fastai/data/camvid/codes.txt')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/camvid/images/0016E5_05970.png'),
#  PosixPath('/root/.fastai/data/camvid/images/Seq05VD_f02970.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_01710.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0006R0_f03270.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0001TP_008880.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:5]
# Out:
# [PosixPath('/root/.fastai/data/camvid/labels/0016E5_06420_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0016E5_04560_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0001TP_007500_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0016E5_01740_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0006R0_f02070_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[ 4,  4,  4,  ...,  4,  4,  4],
#           [ 4,  4,  4,  ...,  4,  4,  4],
#           [ 4,  4,  4,  ...,  4,  4,  4],
#           ...,
#           [19, 19, 19,  ..., 17, 17, 17],
#           [19, 19, 19,  ..., 17, 17, 17],
#           [19, 19, 19,  ..., 17, 17, 17]]]))

# %%
codes = np.loadtxt('/root/.fastai/data/camvid/codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# ## Datasets

# %%
size = src_size//2

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=4
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=4, have 0MB of GPU RAM free

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')             #segment and split the training and test/validation sets defined by the source in valid.txt
       .label_from_func(get_y_fn, classes=codes))       #to know what each pixel is referring to because the mask came as integers instead of string
                                                        #label the data using the get_y_fn (So segmented label's are the file name + "_p") function created earlier
                                                        #classes are defined in codes.txt (to get what each pixel is/created earlier)

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True) #for transformations, size=size refers to using a smaller size, tfm_y=True means when you transform the pictures, always transform the mask too.
        .databunch(bs=bs)                                      #small batch sizes
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
lr=3e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# Total time: 05:30 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.172738</th>
#     <th>0.771233</th>
#     <th>0.820753</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.799105</th>
#     <th>0.637969</th>
#     <th>0.825231</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.731867</th>
#     <th>0.628517</th>
#     <th>0.824456</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.630086</th>
#     <th>0.486045</th>
#     <th>0.860029</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.616145</th>
#     <th>0.535374</th>
#     <th>0.860695</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.588540</th>
#     <th>0.439988</th>
#     <th>0.879501</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.551265</th>
#     <th>0.412592</th>
#     <th>0.884478</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.568172</th>
# ...

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# Total time: 06:39 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.389135</th>
#     <th>0.334715</th>
#     <th>0.896700</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.377873</th>
#     <th>0.324080</th>
#     <th>0.900284</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.369020</th>
#     <th>0.325073</th>
#     <th>0.904146</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.355022</th>
#     <th>0.308820</th>
#     <th>0.912556</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.351138</th>
#     <th>0.313001</th>
#     <th>0.909351</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.347777</th>
#     <th>0.285509</th>
#     <th>0.920183</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.338683</th>
#     <th>0.306076</th>
#     <th>0.909899</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.318913</th>
# ...

# %%
learn.save('stage-2');

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
learn.destroy()

size = src_size

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=3
else:           bs=1
print(f"using bs={bs}, have {free}MB of GPU RAM free")

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# Total time: 20:31 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.366140</th>
#     <th>0.339497</th>
#     <th>0.908682</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.333278</th>
#     <th>0.304011</th>
#     <th>0.916702</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.326025</th>
#     <th>0.305404</th>
#     <th>0.919941</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.336885</th>
#     <th>0.321342</th>
#     <th>0.910933</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.326935</th>
#     <th>0.305589</th>
#     <th>0.919401</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.347779</th>
#     <th>0.333608</th>
#     <th>0.908895</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.328334</th>
#     <th>0.352358</th>
#     <th>0.905482</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.327277</th>
# ...

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)

# %%
learn.fit_one_cycle(10, lrs)
# Out:
# Total time: 21:05 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.225999</th>
#     <th>0.254650</th>
#     <th>0.930782</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.216341</th>
#     <th>0.256007</th>
#     <th>0.930751</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.209800</th>
#     <th>0.255649</th>
#     <th>0.930709</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.203509</th>
#     <th>0.252857</th>
#     <th>0.931682</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.202308</th>
#     <th>0.258498</th>
#     <th>0.931308</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.200796</th>
#     <th>0.257311</th>
#     <th>0.931915</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.204560</th>
#     <th>0.251486</th>
#     <th>0.933218</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.192893</th>
# ...

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');

# %%
learn.show_results(rows=3, figsize=(10,10))

# %% [markdown]
# ## fin
